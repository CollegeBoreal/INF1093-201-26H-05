# %% [markdown]
# # RAPPORT - Dijkstra
#
# **Nom :** Lyes Hamed
# **Numéro étudiant :** 300158486
#
# Ce rapport présente le graphe utilisé dans le travail et le résultat final de l'algorithme de Dijkstra.

# %%
path = ['a', 'c', 'f', 'e']
distance = 20

print('Le plus court chemin :', path)
print('Distance totale :', distance)
# Out:
# Le plus court chemin : ['a', 'c', 'f', 'e']
# Distance totale : 20

# %% [markdown]
# ## Image du graphe
#
# L'image suivante montre le graphe pondéré et le plus court chemin en rouge.

# %%
from IPython.display import Image, display

display(Image(filename='images/dijkstra_graph.png'))

# %% [markdown]
# ## Conclusion
#
# Le plus court chemin entre **a** et **e** est **a → c → f → e**.
#
# La distance totale obtenue est **20**.
