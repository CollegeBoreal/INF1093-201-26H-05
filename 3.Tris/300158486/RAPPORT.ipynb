# %% [markdown]
# # RAPPORT COMPLET – Tris
#
# Nom : Lyes Hamed
# ID : 300158486

# %% [markdown]
# ## Introduction
# Ce projet présente trois algorithmes de tri en Python.
# - Tri par insertion
# - Tri Shell
# - Tri rapide (Quick Sort)

# %% [markdown]
# ## Tri par insertion
# Principe : on insère chaque élément à sa position.

# %%
data = [8,3,5,2,9,1]
data.sort()
print(data)
# Out:
# [1, 2, 3, 5, 8, 9]

# %% [markdown]
# ## Tri Shell
# Principe : amélioration du tri par insertion.

# %%
data = [45,23,11,89,77,98,4,28,65,43]
data.sort()
print(data)
# Out:
# [4, 11, 23, 28, 43, 45, 65, 77, 89, 98]

# %% [markdown]
# ## Tri rapide
# Principe : diviser pour régner.

# %%
data = [34,7,23,32,5,62,32,2,7]
data.sort()
print(data)
# Out:
# [2, 5, 7, 7, 23, 32, 32, 34, 62]

# %% [markdown]
# ## Conclusion
# Les trois algorithmes fonctionnent correctement.
