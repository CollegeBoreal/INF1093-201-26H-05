# %% [markdown]
# # Rapport POO
#
# ID : 300157330
#
# Projet Python utilisant la programmation orientée objet.
#
# Classes utilisées :
# - Figure
# - Carre
# - Cercle
# - Triangle

# %%
from Carre import Carre
from Cercle import Cercle
from Triangle import Triangle

figures = [Carre(5), Cercle(2), Triangle(6, 3)]

for f in figures:
    print(f.description())
# Out:
# Nom de la figure : Carré, côté = 5, aire = 25
# Nom de la figure : Cercle, rayon = 2, aire = 12.57
# Nom de la figure : Triangle, base = 6, hauteur = 3, aire = 9.0

# %% [markdown]
# ## Conclusion
#
# Ce projet montre l’utilisation de la programmation orientée objet avec l’héritage et le polymorphisme.
