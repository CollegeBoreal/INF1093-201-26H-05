# %% [markdown]
# # RAPPORT — Projet POO\n\n**Nom :** BELAID Rabah  \n**ID :** 300158058\n\nCe notebook présente brièvement le projet de programmation orientée objet sur les formes géométriques.

# %% [markdown]
# ## Contenu du projet\n- Classe de base `Figure`\n- Classes dérivées : `Carre`, `Cercle`, `Triangle`, `Cube`\n- Programme principal : `main.py`

# %%
from Carre import Carre\nfrom Cercle import Cercle\nfrom Triangle import Triangle\nfrom Cube import Cube\n\nfigures = [Carre(5), Cercle(4), Triangle(6, 3), Cube(2)]\nfor f in figures:\n    print(f.afficher_info())
