# %% [markdown]
# # 🧮 Étude : Figures Géométriques — Aires, Volumes et Visualisation
#
# |     |              |
# | --- | ------------ |
# | Nom | Ahmed Bergui |
# | 🆔  | 300151262 |
#
# Ce notebook démontre l’utilisation d’une hiérarchie de classes Python :
#
# - `Figure` (classe de base)
# - `Carre`
# - `Cercle`
# - `Triangle`
# - `Cube`
#
# Puis l’affichage graphique grâce à :
#
# - **matplotlib 3.9.2**
# - **numpy 2.1.3**
#
# Nous allons :
# 1. importer les classes
# 2. créer des figures
# 3. afficher leurs aires
# 4. tracer le carré, le cercle, le triangle et un cube 3D

# %%
from Carre import Carre
from Cercle import Cercle
from Triangle import Triangle
from Cube import Cube
from Rectangle import Rectangle
from Sphere import Sphere

c1 = Carre(4)
c2 = Cercle(3)
c3 = Triangle(5, 2)
c4 = Cube(3)
c5 = Rectangle(5, 2)
c6 = Sphere(3)

formes = [c1, c2, c3, c4, c5, c6]

for f in formes:
    print(f.afficher_info())
    print(f"Aire: {f.aire()} 📏")
    if hasattr(f, "volume"):
        print(f"Volume: {f.volume()} 🧊")
# Out:
# Figure: Carré, côté=4, aire=16
# Aire: 16 📏
# Figure: Cercle, rayon=3, aire=28.27
# Aire: 28.274333882308138 📏
# Figure: Triangle, base=5, hauteur=2, aire=5.0
# Aire: 5.0 📏
# Figure: Cube, arête=3, aire=54, volume=27
# Aire: 54 📏
# Volume: 27 🧊
# Rectangle de largeur 5 et hauteur 2
# Aire: 10 📏
# Sphère de rayon 3
# Aire: 113.09733552923255 📏
# Volume: 113.09733552923254 🧊

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
def afficher_carre(carre):
    cote = carre.cote
    x = [0, cote, cote, 0, 0]
    y = [0, 0, cote, cote, 0]

    plt.figure(figsize=(5, 5))
    plt.plot(x, y)
    plt.fill(x, y, alpha=0.3)
    plt.title(f"Carré — côté={cote}, aire={carre.aire()}")
    plt.axis("equal")
    plt.grid(True)
    plt.show()

# %%
def afficher_cercle(cercle):
    r = cercle.rayon
    theta = np.linspace(0, 2*np.pi, 300)

    x = r * np.cos(theta)
    y = r * np.sin(theta)

    plt.figure(figsize=(5, 5))
    plt.plot(x, y)
    plt.fill(x, y, alpha=0.3)
    plt.title(f"Cercle — rayon={r}, aire={cercle.aire():.2f}")
    plt.axis("equal")
    plt.grid(True)
    plt.show()

# %%
def afficher_triangle(triangle):
    base = triangle.base
    hauteur = triangle.hauteur
    x = [0, base, base / 2, 0]
    y = [0, 0, hauteur, 0]

    plt.figure(figsize=(5, 5))
    plt.plot(x, y)
    plt.fill(x, y, alpha=0.3)
    plt.title(f"Triangle — base={base}, hauteur={hauteur}, aire={triangle.aire()}")
    plt.axis("equal")
    plt.grid(True)
    plt.show()

# %%
def afficher_rectangle(rectangle):
    largeur = rectangle.largeur
    hauteur = rectangle.hauteur
    x = [0, largeur, largeur, 0, 0]
    y = [0, 0, hauteur, hauteur, 0]

    plt.figure(figsize=(6, 4))
    plt.plot(x, y)
    plt.fill(x, y, alpha=0.3)
    plt.title(f"Rectangle — largeur={largeur}, hauteur={hauteur}, aire={rectangle.aire()}")
    plt.axis("equal")
    plt.grid(True)
    plt.show()

# %%
def afficher_sphere(sphere):
    r = sphere.rayon
    u = np.linspace(0, 2 * np.pi, 60)
    v = np.linspace(0, np.pi, 60)

    x = r * np.outer(np.cos(u), np.sin(v))
    y = r * np.outer(np.sin(u), np.sin(v))
    z = r * np.outer(np.ones(np.size(u)), np.cos(v))

    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, projection="3d")
    ax.plot_surface(x, y, z, alpha=0.3)

    ax.set_xlim(-r, r)
    ax.set_ylim(-r, r)
    ax.set_zlim(-r, r)
    ax.set_box_aspect([1, 1, 1])
    ax.set_title(f"Sphère — rayon={r}, aire={sphere.aire():.2f}, volume={sphere.volume():.2f}")
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")

# %%
def afficher_cube(cube):
    a = cube.arete
    sommets = np.array([
        [0, 0, 0], [a, 0, 0], [a, a, 0], [0, a, 0],
        [0, 0, a], [a, 0, a], [a, a, a], [0, a, a]
    ])

    faces = [
        [sommets[j] for j in [0, 1, 2, 3]],
        [sommets[j] for j in [4, 5, 6, 7]],
        [sommets[j] for j in [0, 1, 5, 4]],
        [sommets[j] for j in [2, 3, 7, 6]],
        [sommets[j] for j in [1, 2, 6, 5]],
        [sommets[j] for j in [4, 7, 3, 0]],
    ]

    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, projection="3d")
    collection = Poly3DCollection(faces, alpha=0.3)
    ax.add_collection3d(collection)

    ax.scatter(sommets[:, 0], sommets[:, 1], sommets[:, 2])
    ax.set_xlim(0, a)
    ax.set_ylim(0, a)
    ax.set_zlim(0, a)
    ax.set_title(f"Cube — arête={a}, aire={cube.aire()}, volume={cube.volume()}")
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    plt.show()

# %%
afficher_carre(c1)
afficher_cercle(c2)
afficher_triangle(c3)
afficher_cube(c4)
afficher_rectangle(c5)
afficher_sphere(c6)
