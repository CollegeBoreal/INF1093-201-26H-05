# %% [markdown]
# # 🧮 Étude : Figures Géométriques — Aires et Visualisations
#
# Ce notebook montre :
# - La hiérarchie de classes Python : Figure → Carre / Cercle
# - Calcul des aires
# - Visualisation graphique avec matplotlib
