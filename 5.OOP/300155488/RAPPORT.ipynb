# %% [markdown]
# # Nom: Iba KANE
# # ID : 300155488

# %% [markdown]
# # 1. IMPORTS
# print("## 1. Import des classes")
# from Carre import Carre
# from Cercle import Cercle
# import numpy as np
# import matplotlib.pyplot as plt
#
# # 2. CRÉATION DES OBJETS
# print("## 2. Création des objets")
# c1 = Carre(4)
# c2 = Cercle(3)
#
# # 3. AFFICHAGE INFO
# print("## 3. Affichage des informations")
# print(c1.afficher_info())
# print(c2.afficher_info())
# print()
#
# # 4. FONCTION CARRÉ
# print("## 4. Fonction pour afficher un carré")
# def afficher_carre(carre):
#     cote = carre.cote
#     x = [0, cote, cote, 0, 0]
#     y = [0, 0, cote, cote, 0]
#
#     plt.figure(figsize=(5, 5))
#     plt.plot(x, y, color='blue')
#     plt.fill(x, y, alpha=0.3, color='skyblue')
#     plt.title(f"Carré — côté={cote}, aire={carre.aire()}")
#     plt.axis('equal')
#     plt.grid(True)
#     plt.show()
#
# # 5. FONCTION CERCLE
# print("## 5. Fonction pour afficher un cercle")
# def afficher_cercle(cercle):
#     r = cercle.rayon
#     theta = np.linspace(0, 2*np.pi, 300)
#
#     x = r * np.cos(theta)
#     y = r * np.sin(theta)
#
#     plt.figure(figsize=(5, 5))
#     plt.plot(x, y, color='red')
#     plt.fill(x, y, alpha=0.3, color='salmon')
#     plt.title(f"Cercle — rayon={r}, aire={cercle.aire():.2f}")
#     plt.axis('equal')
#     plt.grid(True)
#     plt.show()
#
# # 6. AFFICHAGE GRAPHIQUE
# print("## 6. Affichage des figures")
# afficher_carre(c1)
# afficher_cercle(c2)
#
# # 7. POLYMORPHISME
# print("## 7. Polymorphisme")
# formes = [Carre(4), Cercle(3)]
# for f in formes:
#     print(f"Aire: {f.aire()}")
#
# # 8. NOUVELLE FIGURE : TRIANGLE
# print("\n## 8. Nouvelle figure : Triangle")
# from figure import Figure
#
# class Triangle(Figure):
#     def __init__(self, base, hauteur):
#         super().__init__('Triangle')
#         self.base = base
#         self.hauteur = hauteur
#
#     def aire(self):
#         return (self.base * self.hauteur) / 2
#
#     def afficher_info(self):
#         return f"{super().afficher_info()}, base={self.base}, hauteur={self.hauteur}, aire={self.aire()}"
#
# t1 = Triangle(5, 2)
# print(t1.afficher_info())
#
# # 9. CONCLUSION
# print("\n## 9. Conclusion")
# print("✅ Héritage, polymorphisme, super() et visualisation matplotlib")
# print("La méthode aire() utilise NotImplementedError dans la classe de base [web:2][web:3]")

# %% [markdown]
# from Carre import Carre
# from Cercle import Cercle
# from Triangle import Triangle
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d.art3d import Poly3DCollection
#
#
# # =========================================================
# # DONNÉES
# # =========================================================
# carre = Carre(4)
# cercle = Cercle(3)
# triangle = Triangle(5, 2)
#
# formes = [carre, cercle, triangle]
#
# print("RAPPORT : FIGURES GÉOMÉTRIQUES")
# print("-" * 60)
# print("Informations des figures :\n")
# for f in formes:
#     print(f.afficher_info())
#
# print("\nAires des figures :\n")
# for f in formes:
#     print(f"{f.nom} : {f.aire():.2f}")
#
#
# # =========================================================
# # GRANDE FIGURE UNIQUE : 2D + 3D + 4D
# # =========================================================
# fig = plt.figure(figsize=(18, 12))
# fig.suptitle("Rapport visuel — Figures géométriques en 2D, 3D et 4D", fontsize=18, fontweight="bold")
#
# # -------------------------
# # 1) CARRÉ 2D
# # -------------------------
# ax1 = fig.add_subplot(2, 3, 1)
#
# cote = carre.cote
# x_carre = [0, cote, cote, 0, 0]
# y_carre = [0, 0, cote, cote, 0]
#
# ax1.plot(x_carre, y_carre, color="blue", linewidth=2.5)
# ax1.fill(x_carre, y_carre, color="skyblue", alpha=0.4)
# ax1.set_title(f"Carré (2D)\nCôté = {cote} | Aire = {carre.aire()}")
# ax1.set_xlabel("X")
# ax1.set_ylabel("Y")
# ax1.grid(True, alpha=0.4)
# ax1.set_aspect("equal", adjustable="box")
#
#
# # -------------------------
# # 2) CERCLE 2D
# # -------------------------
# ax2 = fig.add_subplot(2, 3, 2)
#
# r = cercle.rayon
# theta = np.linspace(0, 2 * np.pi, 400)
# x_cercle = r * np.cos(theta)
# y_cercle = r * np.sin(theta)
#
# ax2.plot(x_cercle, y_cercle, color="red", linewidth=2.5)
# ax2.fill(x_cercle, y_cercle, color="salmon", alpha=0.4)
# ax2.set_title(f"Cercle (2D)\nRayon = {r} | Aire = {cercle.aire():.2f}")
# ax2.set_xlabel("X")
# ax2.set_ylabel("Y")
# ax2.grid(True, alpha=0.4)
# ax2.set_aspect("equal", adjustable="box")
#
#
# # -------------------------
# # 3) TRIANGLE 2D
# # -------------------------
# ax3 = fig.add_subplot(2, 3, 3)
#
# base = triangle.base
# hauteur = triangle.hauteur
# x_triangle = [0, base, base / 2, 0]
# y_triangle = [0, 0, hauteur, 0]
#
# ax3.plot(x_triangle, y_triangle, color="green", linewidth=2.5)
# ax3.fill(x_triangle, y_triangle, color="lightgreen", alpha=0.45)
# ax3.set_title(f"Triangle (2D)\nBase = {base} | Hauteur = {hauteur} | Aire = {triangle.aire()}")
# ax3.set_xlabel("X")
# ax3.set_ylabel("Y")
# ax3.grid(True, alpha=0.4)
# ax3.set_aspect("equal", adjustable="box")
#
#
# # -------------------------
# # 4) VISUALISATION 3D PROPRE
# # -------------------------
# ax4 = fig.add_subplot(2, 3, 4, projection="3d")
#
# # Carré 3D
# carre_pts = [
#     [0, 0, 0],
#     [cote, 0, 0],
#     [cote, cote, 0],
#     [0, cote, 0]
# ]
# poly_carre = Poly3DCollection(
#     [carre_pts],
#     facecolors="skyblue",
#     edgecolors="blue",
#     linewidths=2,
#     alpha=0.55
# )
# ax4.add_collection3d(poly_carre)
#
# # Triangle 3D
# triangle_pts = [
#     [0, 0, 4],
#     [base, 0, 4],
#     [base / 2, hauteur, 4]
# ]
# poly_triangle = Poly3DCollection(
#     [triangle_pts],
#     facecolors="lightgreen",
#     edgecolors="green",
#     linewidths=2,
#     alpha=0.65
# )
# ax4.add_collection3d(poly_triangle)
#
# # Cercle 3D (disque dans le plan z=2)
# zc = 2.0
# cercle_pts_3d = [[0, 0, zc]] + [[x_cercle[i], y_cercle[i], zc] for i in range(len(theta))]
# poly_cercle = Poly3DCollection(
#     [cercle_pts_3d],
#     facecolors="salmon",
#     edgecolors="red",
#     linewidths=1.5,
#     alpha=0.5
# )
# ax4.add_collection3d(poly_cercle)
#
# # Contours
# ax4.plot(
#     [p[0] for p in carre_pts] + [carre_pts[0][0]],
#     [p[1] for p in carre_pts] + [carre_pts[0][1]],
#     [p[2] for p in carre_pts] + [carre_pts[0][2]],
#     color="blue",
#     linewidth=2
# )
# ax4.plot(x_cercle, y_cercle, np.full_like(theta, zc), color="red", linewidth=2)
# ax4.plot(
#     [p[0] for p in triangle_pts] + [triangle_pts[0][0]],
#     [p[1] for p in triangle_pts] + [triangle_pts[0][1]],
#     [p[2] for p in triangle_pts] + [triangle_pts[0][2]],
#     color="green",
#     linewidth=2
# )
#
# ax4.set_title("Figures remplies en 3D")
# ax4.set_xlabel("X")
# ax4.set_ylabel("Y")
# ax4.set_zlabel("Z")
# ax4.set_xlim(-4, 6)
# ax4.set_ylim(-4, 6)
# ax4.set_zlim(0, 5)
# ax4.set_box_aspect((10, 10, 5))
# ax4.view_init(elev=24, azim=-58)
#
#
# # -------------------------
# # 5) VISUALISATION 4D PROPRE
# # -------------------------
# ax5 = fig.add_subplot(2, 3, 5, projection="3d")
#
# noms = [f.nom for f in formes]
# x4 = np.array([1, 2, 3], dtype=float)
# y4 = np.array([carre.cote, cercle.rayon, triangle.base], dtype=float)
# z4 = np.array([carre.aire(), cercle.aire(), triangle.aire()], dtype=float)
#
# couleurs = z4
# tailles = z4 * 35
#
# scatter = ax5.scatter(
#     x4, y4, z4,
#     c=couleurs,
#     s=tailles,
#     cmap="viridis",
#     alpha=0.9,
#     edgecolors="black",
#     linewidths=1
# )
#
# for i, nom in enumerate(noms):
#     ax5.text(x4[i] + 0.05, y4[i] + 0.05, z4[i] + 0.4, nom, fontsize=11, weight="bold")
#
# ax5.set_title("Visualisation 4D\n(couleur + taille = aire)")
# ax5.set_xlabel("Indice")
# ax5.set_ylabel("Dimension principale")
# ax5.set_zlabel("Aire")
# ax5.set_xlim(0.5, 3.5)
# ax5.set_ylim(0, 6)
# ax5.set_zlim(0, max(z4) + 5)
# ax5.set_box_aspect((4, 6, 8))
# ax5.view_init(elev=22, azim=-58)
#
# cbar = fig.colorbar(scatter, ax=ax5, shrink=0.7, pad=0.08)
# cbar.set_label("Valeur de l'aire")
#
#
# # -------------------------
# # 6) BARRES DE COMPARAISON
# # -------------------------
# ax6 = fig.add_subplot(2, 3, 6)
#
# noms_barres = [f.nom for f in formes]
# aires_barres = [f.aire() for f in formes]
# couleurs_barres = ["skyblue", "salmon", "lightgreen"]
#
# barres = ax6.bar(noms_barres, aires_barres, color=couleurs_barres, edgecolor="black")
# ax6.set_title("Comparaison des aires")
# ax6.set_ylabel("Aire")
# ax6.grid(axis="y", alpha=0.3)
#
# for barre, valeur in zip(barres, aires_barres):
#     ax6.text(
#         barre.get_x() + barre.get_width() / 2,
#         barre.get_height() + 0.5,
#         f"{valeur:.2f}",
#         ha="center",
#         va="bottom",
#         fontsize=11,
#         fontweight="bold"
#     )
#
# plt.tight_layout(rect=[0, 0, 1, 0.95])
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import math
import os

# ===============================
# DOSSIER
# ===============================
os.makedirs("images", exist_ok=True)

# ===============================
# CLASSES
# ===============================
class Figure:
    def __init__(self, nom):
        self.nom = nom
    def aire(self):
        raise NotImplementedError

class Carre(Figure):
    def __init__(self, cote):
        super().__init__("Carré")
        self.cote = cote
    def aire(self):
        return self.cote ** 2

class Cercle(Figure):
    def __init__(self, rayon):
        super().__init__("Cercle")
        self.rayon = rayon
    def aire(self):
        return math.pi * self.rayon ** 2

class Triangle(Figure):
    def __init__(self, base, hauteur):
        super().__init__("Triangle")
        self.base = base
        self.hauteur = hauteur
    def aire(self):
        return (self.base * self.hauteur) / 2

# ===============================
# DONNÉES
# ===============================
carre = Carre(4)
cercle = Cercle(3)
triangle = Triangle(5, 2)

c = carre.cote
r = cercle.rayon
b = triangle.base
h = triangle.hauteur

# =========================================================
# 2D — CHAQUE FIGURE SEULE
# =========================================================

# ---- Carré
plt.figure(figsize=(6,6))
x = [0,c,c,0,0]
y = [0,0,c,c,0]
plt.plot(x,y,linewidth=3)
plt.fill(x,y,alpha=0.3)
plt.text(c/2,-0.3,f"{c}",ha="center")
plt.text(-0.3,c/2,f"{c}",va="center",rotation=90)
plt.title(f"Carré | Aire={carre.aire():.2f}")
plt.gca().set_aspect("equal")
plt.grid()
plt.savefig("images/carre.png", dpi=300)
plt.show()

# ---- Cercle
plt.figure(figsize=(6,6))
theta = np.linspace(0,2*np.pi,400)
x = r*np.cos(theta)
y = r*np.sin(theta)
plt.plot(x,y,linewidth=3)
plt.fill(x,y,alpha=0.3)
plt.plot([0,r],[0,0],linewidth=2)
plt.text(r/2,0.2,f"r={r}")
plt.title(f"Cercle | Aire={cercle.aire():.2f}")
plt.gca().set_aspect("equal")
plt.grid()
plt.savefig("images/cercle.png", dpi=300)
plt.show()

# ---- Triangle
plt.figure(figsize=(6,6))
x = [0,b,b/2,0]
y = [0,0,h,0]
plt.plot(x,y,linewidth=3)
plt.fill(x,y,alpha=0.3)
plt.text(b/2,-0.3,f"b={b}",ha="center")
plt.plot([b/2,b/2],[0,h],"--")
plt.text(b/2+0.2,h/2,f"h={h}")
plt.title(f"Triangle | Aire={triangle.aire():.2f}")
plt.gca().set_aspect("equal")
plt.grid()
plt.savefig("images/triangle.png", dpi=300)
plt.show()

# =========================================================
# 3D — CHAQUE FIGURE SEULE
# =========================================================

# ---- Carré 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

pts = [[0,0,0],[c,0,0],[c,c,0],[0,c,0]]
ax.add_collection3d(Poly3DCollection([pts], alpha=0.5))
ax.text(c/2, -0.5, 0, f"{c}")
ax.set_title("Carré 3D")
plt.savefig("images/carre_3d.png", dpi=300)
plt.show()

# ---- Cercle 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

theta = np.linspace(0,2*np.pi,200)
x = r*np.cos(theta)
y = r*np.sin(theta)
z = np.zeros_like(theta)

ax.plot(x,y,z,linewidth=3)
ax.plot([0,r],[0,0],[0,0])
ax.text(r/2,0,0,f"r={r}")
ax.set_title("Cercle 3D")
plt.savefig("images/cercle_3d.png", dpi=300)
plt.show()

# ---- Triangle 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

pts = [[0,0,0],[b,0,0],[b/2,h,0]]
ax.add_collection3d(Poly3DCollection([pts], alpha=0.6))
ax.text(b/2,-0.5,0,f"b={b}")
ax.text(b/2,h/2,0,f"h={h}")
ax.set_title("Triangle 3D")
plt.savefig("images/triangle_3d.png", dpi=300)
plt.show()


plt.show()
