# %% [markdown]
#  Étude : Figures Géométriques — Aires, Volumes et Visualisation
#
# |     |              |
# | --- | ------------ |
# | Nom | Mohammed Mati |
# | 🆔  | 300158185 |
#
# Ce notebook démontre l’utilisation d’une hiérarchie de classes Python :
#
# - `Figure` (classe de base)
# - `Carre`
# - `Cercle`
# - `Triangle`
# Puis l’affichage graphique grâce à :
#
# - **matplotlib 3.9.2**
# - **numpy 2.1.3**
#
# Nous allons :
# 1. importer les classes
# 2. créer des figures
# 3. afficher leurs aires
# 4. tracer le carré, le cercle, le triangle et un cube 3D

# %%
import numpy as np
import matplotlib.pyplot as plt
from Carre import Carre
from Cercle import Cercle
from Triangle import Triangle
from Rectangle import Rectangle
from Losange import Losange
from Trapeze import Trapeze
from Parallelogramme import Parallelogramme
from Pentagone import Pentagone
from Hexagone import Hexagone
from Octogone import Octogone
from Ellipse import Ellipse
from Etoile import Etoile
from Cube3D import Cube3D

from visualisation_formes import (
    afficher_carre, afficher_cercle, afficher_triangle, afficher_rectangle,
    afficher_losange, afficher_trapeze, afficher_parallelogramme,
    afficher_pentagone, afficher_hexagone, afficher_octogone,
    afficher_ellipse, afficher_etoile, afficher_cube_3d
)

# %%
formes = [
    Carre(4),
    Cercle(3),
    Triangle(5, 2),
    Rectangle(6, 3),
    Losange(6, 4),
    Trapeze(8, 4, 3),
    Parallelogramme(6, 3, 2),
    Pentagone(3),
    Hexagone(3),
    Octogone(3),
    Ellipse(4, 2),
    Etoile(4, 2, 5),
    Cube3D(3)
]

for f in formes:
    print(f.afficher_info())
    try:
        print(f"Aire: {f.aire()}")
    except Exception as e:
        print(f"Aire non disponible: {e}")
    if hasattr(f, "volume"):
        print(f"Volume: {f.volume()}")
    print("-")
# Out:
# Carré de côté 4
# Aire: 16
# -
# Cercle de rayon 3
# Aire: 28.274333882308138
# -
# Triangle de base 5 et hauteur 2
# Aire: 5.0
# -
# Rectangle de longueur 6 et largeur 3
# Aire: 18
# -
# Losange de diagonales 6 et 4
# Aire: 12.0
# -
# Trapèze de bases 8 et 4, hauteur 3
# Aire: 18.0
# -
# Parallélogramme de base 6 et hauteur 3
# Aire: 18
# -
# Pentagone régulier de rayon 3
# Aire: 21.398771616640953
# -
# Hexagone régulier de rayon 3
# Aire: 23.38268590217984
# -
# Octogone régulier de rayon 3
# Aire: 25.455844122715714
# -
# Ellipse de demi-axes 4 et 2
# Aire: 25.132741228718345
# -
# Étoile de 5 branches
# Aire: Aire approximative non définie dans ce projet
# -
# Cube 3D de côté 3
# Aire: 54
# Volume: 27
# -

# %%
afficher_carre(formes[0])
afficher_cercle(formes[1])
afficher_triangle(formes[2])
afficher_rectangle(formes[3])
afficher_losange(formes[4])
afficher_trapeze(formes[5])
afficher_parallelogramme(formes[6])
afficher_pentagone(formes[7])
afficher_hexagone(formes[8])
afficher_octogone(formes[9])
afficher_ellipse(formes[10])
afficher_etoile(formes[11])
afficher_cube_3d(formes[12])
