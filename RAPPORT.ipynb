# %% [markdown]
# # Rapport – Algorithme de Dijkstra
#
# Ce notebook montre :
# - La représentation du graphe
# - L'application de l'algorithme de Dijkstra
# - La visualisation du plus court chemin

# %%
# RAPPORT.ipynb
import networkx as nx
import matplotlib.pyplot as plt
from dijkstra_tp import g, shortest

# Création du graphe NetworkX
G = nx.Graph()

for v in g:
    for w in v.get_connections():
        G.add_edge(v.get_id(), w.get_id(), weight=v.get_weight(w))

# Positionnement automatique
pos = nx.spring_layout(G)

# Dessin des noeuds et arêtes
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=2000)

# Ajouter les poids
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

# Mettre en évidence le plus court chemin
start = g.get_vertex('Paris')
target = g.get_vertex('Rome')
path = shortest(target)

# Dessiner le chemin en rouge
path_edges = list(zip(path, path[1:]))
nx.draw_networkx_edges(G, pos, edgelist=path_edges, edge_color='red', width=3)

plt.title("Graphe des villes et plus court chemin de Paris à Rome")
plt.show()
# Out:
# Graph data:
# ( Paris , Londres,   7 )
# ( Paris , Berlin,   9 )
# ( Paris , Bruxelles,  14 )
# ( Londres , Paris,   7 )
# ( Londres , Berlin,  10 )
# ( Londres , Madrid,  15 )
# ( Berlin , Paris,   9 )
# ( Berlin , Londres,  10 )
# ( Berlin , Madrid,  11 )
# ( Berlin , Bruxelles,   2 )
# ( Madrid , Londres,  15 )
# ( Madrid , Berlin,  11 )
# ( Madrid , Rome,   6 )
# ( Rome , Madrid,   6 )
# ( Rome , Bruxelles,   9 )
# ( Bruxelles , Paris,  14 )
# ( Bruxelles , Berlin,   2 )
# ( Bruxelles , Rome,   9 )
# updated : current = Paris next = Londres new_dist = 7
# updated : current = Paris next = Berlin new_dist = 9
# updated : current = Paris next = Bruxelles new_dist = 14
# not updated : current = Londres next = Berlin new_dist = 9
# updated : current = Londres next = Madrid new_dist = 22
# updated : current = Berlin next = Madrid new_dist = 20
# updated : current = Berlin next = Bruxelles new_dist = 11
# updated : current = Bruxelles next = Rome new_dist = 20
# not updated : current = Madrid next = Rome new_dist = 20
# Le plus court chemin: ['Paris', 'Berlin', 'Bruxelles', 'Rome']
