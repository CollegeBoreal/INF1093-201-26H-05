# %% [markdown]
# IBA KANE

# %%
a=2
b=3  
c=4
print("avant permutation")
print("a= ",a," b= ",b," c= ",c)
a, b, c = c, a, b  
print("après permutation")
print("a= ",a," b= ",b," c= ",c)
# Out:
# avant permutation
# a=  2  b=  3  c=  4
# après permutation
# a=  4  b=  2  c=  3
