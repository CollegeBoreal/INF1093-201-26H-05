# %% [markdown]
# # TP 2 - Jupyter
#
# | Champ | Valeur |
# |-------|--------|
# | Nom | Souleymane Barry |
# | Numéro étudiant | 300141685 |
# | Cours | INF1093-201-26H-05 |

# %%
import sys

print("=== Informations étudiant ===")
print("Nom    : Souleymane Barry")
print("Numéro : 300141685")
print("Cours  : INF1093-201-26H-05")
print()

print("=== Environnement ===")
print(f"Python    : {sys.version}")
print(f"Exécutable : {sys.executable}")

# %% [markdown]
# ## Vérification de l'installation
#
# Ce notebook confirme que Jupyter est correctement installé et fonctionnel.
