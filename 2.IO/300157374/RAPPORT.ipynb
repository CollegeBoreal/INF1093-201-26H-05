# %% [markdown]
# # Rapport de participation
#
# ID : 300157374
#
# Ce notebook montre la lecture et l’écriture de fichiers en Python.

# %%
texte = "ceci est un texte d'entrée\nil sera transformé en majuscules"

print(texte)
print(texte.upper())
# Out:
# ceci est un texte d'entrée
# il sera transformé en majuscules
# CECI EST UN TEXTE D'ENTRÉE
# IL SERA TRANSFORMÉ EN MAJUSCULES
