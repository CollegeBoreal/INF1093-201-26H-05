# %% [markdown]
# **Ahmed BERGUI**
# 🆔 **300151262**
# **INF1093 – Traitement des entrées/sorties**
# 02 février 2026
#
# ---

# %%
noms = []
notes = []

with open("etudiants.txt", "r") as f:
    for ligne in f:
        nom, note = ligne.split()
        noms.append(nom)
        notes.append(int(note))

# %%
moyenne = sum(notes) / len(notes)
moyenne
round(moyenne, 2)
# Out:
# 55.56

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 8.1/8.1 MB 3.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 225.2/225.2 kB 4.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.3/2.3 MB 3.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 73.5/73.5 kB 4.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 12.6/12.6 MB 3.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.0/7.0 MB 3.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 122.8/122.8 kB 2.4 MB/s eta 0:00:00
# ...
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\rozin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))  # agrandir le graphique

plt.bar(noms, notes)
plt.axhline(moyenne, linestyle='--', label=f"Moyenne : {round(moyenne, 2)}")

plt.xlabel("Étudiant.e.s")
plt.ylabel("Notes")
plt.title("Notes des étudiant.e.s avec moyenne")

plt.xticks(rotation=45, ha="right")  # rotation des noms
plt.legend()
plt.tight_layout()  # ajuste automatiquement l'espace

plt.show()
