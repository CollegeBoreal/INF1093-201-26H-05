# %%
# Rapport IO

Signature
Walid Dahmane - 300151589

# %%
print("Walid Dahmane - 300151589")

# %%
import matplotlib.pyplot as plt

print("Rapport IO")

x = [1, 2, 3]
y = [10, 20, 15]

plt.plot(x, y)
plt.title("Graph")
plt.show()
# Out:
# Rapport IO
